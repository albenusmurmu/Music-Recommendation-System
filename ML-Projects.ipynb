# %%
# import pandas as pd
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score

# # Import data
# music_data = pd.read_csv('music.csv')

# # Separate input features and target
# x = music_data.drop(columns=['genre'])
# y = music_data['genre']
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)


# # Create and train the model
# model = DecisionTreeClassifier()
# # model.fit(x, y)
# model.fit(x_train, y_train)

# # Make predictions
# # predictions = model.predict(
# #     pd.DataFrame([[21, 1], [22, 0]], columns=x.columns)
# # )
# predictions = model.predict(x_test)

# predictions

# score = accuracy_score(y_test, predictions)
# score
# Out:
# 0.75

# %%
# import os

# print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'ML-Projects.ipynb', 'music.csv', 'Untitled.ipynb', 'vgsales.csv']

# %%
# import pandas as pd
# from sklearn.tree import DecisionTreeClassifier
# import joblib

# # Import data
# music_data = pd.read_csv('music.csv')

# # Separate input features and target
# x = music_data.drop(columns=['genre'])
# y = music_data['genre']

# # Create and train the model
# model = DecisionTreeClassifier()
# model.fit(x, y)

# # Save the trained model
# joblib.dump(model, 'music-recommender.joblib')

# # Load the saved model
# model = joblib.load('music-recommender.joblib')

# # Make predictions
# predictions = model.predict([[21, 1]])

# # Display prediction
# predictions
# Out:
# C:\Users\CloudyCoders\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop'], dtype=object)

# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# Load the music dataset
music_data = pd.read_csv('music.csv')

# Separate input features from the target
x = music_data.drop(columns=['genre'])
y = music_data['genre']

# Create the Decision Tree model
model = DecisionTreeClassifier()

# Train the model
model.fit(x, y)

# Export the trained Decision Tree as a .dot file
tree.export_graphviz(
    model,
    out_file='music-recommender.dot',
    feature_names=['age', 'gender'],
    class_names=sorted(y.unique()),
    label='all',
    rounded=True,
    filled=True
)
